# %%
import numpy as np

# %%
arr1 = np.array([12,13,14])

# %%
arr2 = np.array([12,13,14])

# %%
res = np.concatenate([arr1,arr2])

# %%
res
# Out:
# array([12, 13, 14, 12, 13, 14])

# %%
arr_two = np.array([[10,20],[40,50]])

# %%
arr_two1 = np.array([[11,21],[41,51]])

# %%
result = np.concatenate((arr_two,arr_two1),axis = 0)

# %%
result
# Out:
# array([[10, 20],
#        [40, 50],
#        [11, 21],
#        [41, 51]])

# %%
result2 = np.concatenate((arr_two,arr_two1),axis = 1)

# %%
result2
# Out:
# array([[10, 20, 11, 21],
#        [40, 50, 41, 51]])

# %%
a = np.array([1,2,3])

# %%
b = np.array([7,8,9])

# %%
c = np.hstack((a,b))

# %%
c
# Out:
# array([1, 2, 3, 7, 8, 9])

# %%
d = np.vstack((a,b))

# %%
d
# Out:
# array([[1, 2, 3],
#        [7, 8, 9]])

# %%
a2d = np.array([[4,5,6],[9,8,7]])

# %%
b2d = np.array([[1,2,3],[11,12,13]])

# %%
c2d = np.hstack((a2d,b2d))

# %%
c2d
# Out:
# array([[ 4,  5,  6,  1,  2,  3],
#        [ 9,  8,  7, 11, 12, 13]])

# %%
d2d = np.vstack((a2d,b2d))

# %%
d2d
# Out:
# array([[ 4,  5,  6],
#        [ 9,  8,  7],
#        [ 1,  2,  3],
#        [11, 12, 13]])

# %%
name = np.array(["Alice","Bob","Charlie"])

# %%
score = np.array([70,80,90])
