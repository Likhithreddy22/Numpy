# %%
import numpy as np

# %%
a1 = np.array([10,20,30,40,50,60,70,80])

# %%
a1[5]
# Out:
# np.int64(60)

# %%
a1[-3]
# Out:
# np.int64(60)

# %%
a1[-1]
# Out:
# np.int64(80)

# %%
a2 = np.array([[1,5,7],[6,7,8],[9,2,3]])

# %%
a2
# Out:
# array([[1, 5, 7],
#        [6, 7, 8],
#        [9, 2, 3]])

# %%
a2[1,2]
# Out:
# np.int64(8)

# %%
a2[2,0]
# Out:
# np.int64(9)

# %%
a3 = np.array([1,2,3,4,5,6,7])

# %%
a3[2:6]
# Out:
# array([3, 4, 5, 6])

# %%
a3[1:]
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
a3[:4]
# Out:
# array([1, 2, 3, 4])

# %%
a3[-5:-1]
# Out:
# array([3, 4, 5, 6])

# %%
a2[0:2,1:2]
# Out:
# array([[5],
#        [7]])

# %%
a2[0:2,0:2]
# Out:
# array([[1, 5],
#        [6, 7]])

# %%
b = a2>4

# %%
b
# Out:
# array([[False,  True,  True],
#        [ True,  True,  True],
#        [ True, False, False]])

# %%
a2[b]
# Out:
# array([5, 7, 6, 7, 8, 9])
